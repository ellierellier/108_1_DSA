# %%
import random
test_array = [7,12,2,4]
array1 = []
for nums in range(6):
    array1.append(random.randrange(1,100))
print(array1)

class Max_HeapSort:
    def __init__(self, arr):
        for num in arr:
            num.val = num
    
    def heap_index(self, i):
        self.index = i
        self.parent_index = (i-1)/2
        self.left_index = 2i+1
        self.right_index = 2i+2
    
    def heapify_down(self,val,i):
        if i.left_index > i.right_index:
            if val.left_index > val.index:
                swap(i,left_index)
        elif val.left_index < val.right_index:
            if val.right_index > val.index:
                swap(i,right_index)
            
    def swap(self,arr, i1, i2):
        arr[i1],arr[i2] = arr[i2],arr[i1]

# %%
arr = [7,12,2,4]
class Max_heap:
    def __init__(self,arr):
        maxi = arr[0]
        for num in arr:
            node(num)
            
    def node(self,n):
        self.n = n
        
    def find_index(self,i):
        self.left_node = 2*i+1
        self.right_node = 2*i+2
        self.main_node = (i-1)/2
    
    def swap(self,i1,i2):
        arr[i1], arr[i2] = arr[i2], arr[i1]

    def heapify_down(self,arr,maxi,i):
        if maxi < left_node:
            swap(maxi,left_node)
            
heap1 = Max_heap(arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cf2cbd4d8df0> in <module>
#      21             swap(maxi,left_node)
#      22
# ---> 23 heap1 = Max_heap(arr)
#      24
#      25
#
# <ipython-input-1-cf2cbd4d8df0> in __init__(self, arr)
#       4         maxi = arr[0]
#       5         for num in arr:
# ----> 6             node(num)
#       7
#       8     def node(self,n):
#
# NameError: name 'node' is not defined

# %%
arr = [7,12,2,4]
# print(*arr)

maxi = arr[0]
m_index = 0
size = len(arr)

def find_index(i):
    main_index = (i-1)//2
    left_index = 2*i+1
    right_index =2*i+2
    return [main_index, left_index, right_index]

if arr[find_index(0)[1]] < arr[find_index(0)[2]]:
    if arr[find_index(0)[2]] > arr[0]:
        arr[0], arr[find_index(0)[2]] = arr[find_index(0)[2]], arr[0]
elif arr[find_index(0)[1]] > arr[find_index(0)[2]]:
    if arr[find_index(0)[1]] > arr[0]:
        arr[0], arr[find_index(0)[1]] = arr[find_index(0)[1]], arr[0]
        if find_index(1)[2] < len(arr) and arr[find_index(1)[1]] > arr[find_index(1)[2]] :
            if arr[find_index(1)[1]] > arr[1]:
                arr[1], arr[find_index(1)[1]] = arr[find_index(1)[1]] , arr[1]
        elif find_index(1)[2] < len(arr) and arr[find_index(1)[1]] > arr[find_index(1)[2]]:
            if arr[find_index(1)[2]] > arr[1]:
                arr[1], arr[find_index(1)[2]] = arr[find_index(1)[1]] , arr[2]
                
arr [0], arr[len(arr)-1] = arr[len(arr)-1], arr [0]

if arr[find_index(0)[1]] < arr[find_index(0)[2]]:
    if arr[find_index(0)[2]] > arr[0]:
        arr[0], arr[find_index(0)[2]] = arr[find_index(0)[2]], arr[0]
elif arr[find_index(0)[1]] > arr[find_index(0)[2]]:
    if arr[find_index(0)[1]] > arr[0]:
        arr[0], arr[find_index(0)[1]] = arr[find_index(0)[1]], arr[0]
        if find_index(1)[2] < len(arr)-1 and arr[find_index(1)[1]] > arr[find_index(1)[2]] :
            if arr[find_index(1)[1]] > arr[1]:
                arr[1], arr[find_index(1)[1]] = arr[find_index(1)[1]] , arr[1]
        elif find_index(1)[2] < len(arr)-1 and arr[find_index(1)[1]] > arr[find_index(1)[2]]:
            if arr[find_index(1)[2]] > arr[1]:
                arr[1], arr[find_index(1)[2]] = arr[find_index(1)[1]] , arr[2]
                
arr [0], arr[len(arr)-2] = arr[len(arr)-2], arr [0]

if find_index(0)[2]<len(arr)-2 and arr[find_index(0)[1]] < arr[find_index(0)[2]]:
    if arr[find_index(0)[2]] > arr[0]:
        arr[0], arr[find_index(0)[2]] = arr[find_index(0)[2]], arr[0]
elif find_index(0)[2]<len(arr)-2 and arr[find_index(0)[1]] > arr[find_index(0)[2]]:
    if arr[find_index(0)[1]] > arr[0]:
        arr[0], arr[find_index(0)[1]] = arr[find_index(0)[1]], arr[0]
        if find_index(1)[2] < len(arr)-2 and arr[find_index(1)[1]] > arr[find_index(1)[2]] :
            if arr[find_index(1)[1]] > arr[1]:
                arr[1], arr[find_index(1)[1]] = arr[find_index(1)[1]] , arr[1]
        elif find_index(1)[2] < len(arr)-2 and arr[find_index(1)[1]] > arr[find_index(1)[2]]:
            if arr[find_index(1)[2]] > arr[1]:
                arr[1], arr[find_index(1)[2]] = arr[find_index(1)[1]] , arr[2]

# for a in arr:
#     print(find_index(a))
# arr

# if maxi < arr[find_index(0)[1]]:
#     arr[0], arr[find_index(0)[1]] = arr[find_index(0)[1]], arr[0]
print(arr)
# Out:
# [2, 4, 7, 12]

# %%
arr = [7,12,2,4]

class heapsort:
    def find_index(self,arr):
        for n in arr:
            
    
    def find_index_val(self,i):
        self.head = arr[(i-1)//2]
        self.left = arr[2*i+2]
        self.right = arr[2*i+2]

arr.find_index()
# Out:
#   File "<ipython-input-67-e53663f8ac23>", line 18
#     def heapify_down(i,,size):
#                        ^
# SyntaxError: invalid syntax

# %%
arr = [7,12,2,4]
top=0
class max_heap:
    
    def find_index(self,i):
        self.head_i = (i-1)//2
        self.left_i = 2*i+1
        self.right_i = 2*i+2
    
    def swap(i1,i2):
        arr[i1],arr[i2] = arr[i2],arr[i1]
    
    def heapify_down(self, i, arr,cur_len): 
        #top是從index0開始往下比大小，i可以透過find_index取得子節點，cur_len表示這回合需比較的長度
        while i.right_i <= cur_len-1 and arr[i] < arr[i.left_i]:
            swap(i,i.left_i)
            i=2*i+1
            
        while i.right_i <= cur_len-1 and arr[i.head_i] < arr[i.right_i]:
            swap(i.head_i,i.right_i)
            i=2*i+2
# Out:
# 0

# %%
arr = [7,12,2,4]
top=0
class max_heap:
    
    def find_index(self,i):
        self.head_i = (i-1)//2
        self.left_i = 2*i+1
        self.right_i = 2*i+2         
    
    def swap(i1,i2):
        arr[i1],arr[i2] = arr[i2],arr[i1]
    
    def heapify_down(self, i, arr,cur_len): 
        #top是從index0開始往下比大小，i可以透過find_index取得子節點，cur_len表示這回合需比較的長度
        while i.right_i <= cur_len-1 and (arr[i.left_i] > arr[i.right_i] or arr[i.right_i] > arr[i.left_i]):
            if arr[i.left_i] > arr[i.right_i] and arr[i.left_i] > arr[i]:
                swap(i,i.left_i)
                i=2*i+1
            if arr[i.right_i] > arr[i.left_i] and arr[i.right_i] > arr[i]:
                swap(i,i.right_i)
                i=2*i+2
            
        while i.right_i <= cur_len-1 and arr[i.head_i] < arr[i.right_i]:
            swap(i.head_i,i.right_i)
            i=2*i+2

# %%
arr = [7,12,2,4]
top=0
class max_heap:
    
    def find_index(self,i):
        self.head_i = (i-1)//2
        self.left_i = 2*i+1
        self.right_i = 2*i+2
    
    def swap(i1,i2):
        arr[i1],arr[i2] = arr[i2],arr[i1]
    
    def heapify_down(self, i, arr, cur_len): 
        #top是從index0開始往下比大小，i可以透過find_index取得子節點，cur_len表示這回合需比較的長度
        while i.right_i <= cur_len-1 and (arr[i.left_i] > arr[i] or arr[i.right_i] > arr[i]):
            if arr[i.left_i] > arr[i]:
                swap(i,i.left_i)
                heapify(left_i, arr, cur_len)
                
            if arr[i.right_i] > arr[i]:
                swap(i,i.right_i)
                heapify(right_i, arr, cur_len)
        #從上往下比大小會導致沒法窮盡比較所有節點，因此需要迴圈迭代

# %%
arr = [7,12,2,4]
top=0
class max_heap:
    def find_index(self,i):
        self.left_i = 2*i+1
        self.right_i = 2*i+2
    
    def swap(i1,i2):
        arr[i1],arr[i2] = arr[i2],arr[i1]
    
    def heapify_up(self, i, arr, cur_len=len(arr)): 
        #i可以透過find_index取得子節點，cur_len表示這回合需比較的長度
        self.find_index(i)
        while self.right_i <= cur_len-1 and (arr[self.left_i] > arr[i] or arr[self.right_i] > arr[i]):
            if arr[self.left_i] > arr[i]:
                swap(i, self.left_i) #這樣寫會出現NameError: name 'swap' is not defined
                heapify_up(left_i, arr, cur_len)
                
            if arr[self.right_i] > arr[i]:
                self.swap(i, self.right_i) #這樣寫會出現TypeError: swap() takes 2 positional arguments but 3 were given
                heapify_up(right_i, arr, cur_len)
    
    def extract_down(self, arr, top=0, cur_len = len(arr)-1):
        swap(top,cur_len)
        heapify_up(arr, top, cur_len)
        cur_len -= 1
        extract_down(arr, top, cur_len)
        if cur_len<=0:
            return arr
    
heap1 = max_heap()
for element in range(len(arr),-1,-1):
    heap1.heapify_up(element, arr, cur_len=len(arr))
heap1.extract_down(top, arr, cur_len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-ef98afaa76e7> in <module>
#      31 heap1 = max_heap()
#      32 for element in range(len(arr),-1,-1):
# ---> 33     heap1.heapify_up(element, arr, cur_len=len(arr))
#      34 heap1.extract_down(top, arr, cur_len)
#
# <ipython-input-12-ef98afaa76e7> in heapify_up(self, i, arr, cur_len)
#      14         while self.right_i <= cur_len-1 and (arr[self.left_i] > arr[i] or arr[self.right_i] > arr[i]):
#      15             if arr[self.left_i] > arr[i]:
# ---> 16                 self.swap(i, self.left_i) #這樣寫會出現NameError: name 'swap' is not defined
#      17                 heapify_up(left_i, arr, cur_len)
#      18
#
# TypeError: swap() takes 2 positional arguments but 3 were given

# %%
arr = [7,12,2,4]
